# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
pk1 = np.loadtxt('../scripts/Pk128.txt')
plt.loglog(pk1[:,0], pk1[:,1])
pk0 = np.loadtxt('../scripts/Pk512.txt')
plt.loglog(pk0[:,0], pk0[:,1])
pk = np.loadtxt('../scripts/Pk2000.txt')
plt.loglog(pk[:,0], pk[:,1], linestyle='dashed')
plt.grid()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
