# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
pk = np.loadtxt('../output/Pk.txt')
plt.loglog(pk[:,0], pk[:,1]*3)
pk0 = np.loadtxt('../data/Pk128.txt')
plt.loglog(pk0[:,0], pk0[:,1])
# pk1 = np.loadtxt('../data/Pk512.txt')
# plt.loglog(pk1[:,0], pk1[:,1])
pk2 = np.loadtxt('../data/Pk2000.txt')
plt.loglog(pk2[:,0], pk2[:,1], linestyle='dashed')
plt.grid()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
pk = np.loadtxt('/jet/home/dengyw/yujiehe/yujiehe/power_spec/snapshot_550/Pk.txt')
plt.loglog(pk[:,0], pk[:,1])
plt.grid()
