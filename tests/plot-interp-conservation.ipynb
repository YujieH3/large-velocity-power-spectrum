# %%
import matplotlib.pyplot as plt
plt.style.use('./nice.mplstyle')
import numpy as np

fig, ax = plt.subplots(figsize=(7, 7))
ax.scatter([0.98484, 1.00867], [0.98376, 1.00786], marker='+', s=100, label='70% filled cell')
ax.scatter([0.99861, 1.02037], [0.99719, 1.01968], marker='x', s=100, label='100% filled cell')
ax.scatter([1.09099], [1.08632], marker='o', s=100, label='maximize')
ax.scatter([0.95300], [0.95349], marker='*', s=100, label='d > 0.5 Lcell - R')
ax.scatter([0.98497, 0.98600], [0.98384, 0.98521], marker='s', s=100, alpha=0.5, label='ANN')
ax.scatter([1.00023, 1.00212], [0.99998, 1.00187], marker='^', s=100, label='Voxelize plus ANN')

ax.axhline(1, color='k', linestyle='--')
ax.axvline(1, color='k', linestyle='--')
ax.set_xlabel('Mass restored')
ax.set_ylabel('Kinetic energy restored')
ax.legend()
plt.show()
