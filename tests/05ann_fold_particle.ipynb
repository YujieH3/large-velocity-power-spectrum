# %% [markdown]
# # ANN + fold particle is not impossible?

# %%
import numpy as np
import sys
sys.path.append('../vpower')
from spctrm import *
from interp import *
SNAPSHOT = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind0_gmc9/snapshot_550.hdf5'
p = load_snapshot(SNAPSHOT)

# %%
p.pos = fold_particles(p.pos, m=8)
p.Lbox = 1.0 / 8

# %%
f = p.ann_interp_to_field(Nsize=512)

# %%
spctrm = f.spctrm()
# Out:
# Specific kinetic energy before FFT: 2.11e+02
# Specific kinetic energy after FFT: 2.11e+02
# Conserved quantity after sampling: 1.81e+02

# %%
import matplotlib.pyplot as plt
spctrm.plot()
plt.show()
# Out:
# <Axes: xlabel='$k\\,\\mathrm{(kpc^{-1})}$', ylabel='$P(k)\\,\\mathrm{(km^2\\,s^{-2}\\,kpc^{-1})}$'>
