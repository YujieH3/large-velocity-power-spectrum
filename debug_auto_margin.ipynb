# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from utils_folding import *
SNAPSHOT = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind4_gmc9/snapshot_550.hdf5'
simParticles = SimulationParticles.load_snapshot(SNAPSHOT, remove_bulk_velocity=True, shift_to_origin=True)
noPadSimField3D = simParticles.interp_field(Nsize=128, smoothing_rate=1., auto_padding=False)
padSimField3D = simParticles.interp_field(Nsize=128, smoothing_rate=1., auto_padding=True)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 31576651 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	2.821e+07 exact calculations (R>Rmax),
# 	3.364e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 31576651 numbers in 980 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.7427 seconds
# In the end, 0 in cpu_queue
# Padding:  0.04116758416095456 Lbox:  1.0823351683219091 Nsize:  138
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 31432684 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	2.805e+07 exact calculations (R>Rmax),
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].imshow(noPadSimField3D.vx[:64,64:,64])
ax[1].imshow(padSimField3D.vx[:64,64:,64])
plt.show()
