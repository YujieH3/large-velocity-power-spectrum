# %%
# %load_ext autoreload
# %autoreload 2
from vpower.interp import GasParticles
from vpower.interp import load_snapshot
Nsize = 256

SNAPSHOT = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind0_gmc9/snapshot_550.hdf5'
gasPar = load_snapshot(SNAPSHOT)
box = gasPar.ann_interp_to_field(Nsize=256, eps=0.1, treetype='bd',searchtype='priority')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
box.peek()
