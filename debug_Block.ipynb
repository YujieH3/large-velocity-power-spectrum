# %%
# Import voxelize
import sys
sys.path.append('/appalachia/d6/yujie/voxelize-master/voxelize')
sys.path.append('/appalachia/d6/yujie/voxelize-master')
import voxelize
from voxelize import Voxelize
Voxelize.__init__(self=Voxelize, use_gpu=False, network_dir=None)
# Out:
# Only the CPU-only flavour of Voxelize is available!

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
import matplotlib.pyplot as plt
import h5py
import numpy as np

import matplotlib.colors as colors
import seaborn as sns

import utils_data as dt
import utils_pk as pk
import utils_voxelize as vxl
import os

plt.style.use('./niceplot2jay.mplstyle')
# Out:
# Only the CPU-only flavour of Voxelize is available!

# %% [markdown]
# ## Examine Data

# %%
file = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind4_gmc9/snapshot_550.hdf5'
pos, mass, rho, v = dt.PrepSnapshot(file)
v_grid, m_grid = vxl.VoxelizeInterpolate(pos, mass, rho, v, Lbox=1., Nsize=128, smoothing_rate=2.)
V = mass / rho
R = ((3*V)/(4*np.pi))**(1/3) # To check radius distribution
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 81272994 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.485e+07 exact calculations (R>Rmax),
# 	6.422e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 81272994 numbers in 2498 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 14.8094 seconds
# In the end, 0 in cpu_queue

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(v_grid[:,:,30,0])
axes[1].hist(R*2, log=True) # h = R * smoothing_rate
plt.show()

# %% [markdown]
# Final run

# %%
file = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind4_gmc9/snapshot_550.hdf5'
pos, mass, rho, v = dt.PrepSnapshot(file)
data_folder = vxl.InterpBlocksVelocity(pos, mass, rho, v, 
  Lbox=1., Nblock=4, Nsize_blk=64, margin=10/64, 
  smoothing_rate=2., scheme='voxelize', output_folder='./output')
# Out:
# Block length: 0.328125 Block Nsize: 84
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9151222 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.798e+06 exact calculations (R>Rmax),
# 	1.354e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9151222 numbers in 295 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.4523 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 10328340 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.954e+06 exact calculations (R>Rmax),
# 	1.374e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 10328340 numbers in 334 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.4616 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 11657162 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.007e+07 exact calculations (R>Rmax),
# 	1.587e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 11657162 numbers in 375 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.6359 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 7701301 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.136e+06 exact calculations (R>Rmax),
# 	1.565e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 7701301 numbers in 253 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.8383 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8211864 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.560e+06 exact calculations (R>Rmax),
# 	1.652e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8211864 numbers in 265 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.0895 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 9613558 numbers in 311 CPU-chunks.
# root_add_process : ended.
# Workers processed 9613558 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.868e+06 exact calculations (R>Rmax),
# 	1.746e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 2.3909 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8145521 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	5.676e+06 exact calculations (R>Rmax),
# 	2.469e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8145521 numbers in 268 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.1092 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6609854 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	4.341e+06 exact calculations (R>Rmax),
# 	2.269e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6609854 numbers in 219 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.8527 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 6131140 numbers in 204 CPU-chunks.
# root_add_process : ended.
# Workers processed 6131140 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	3.851e+06 exact calculations (R>Rmax),
# 	2.280e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 1.5729 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 7887920 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	5.701e+06 exact calculations (R>Rmax),
# 	2.187e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 7887920 numbers in 260 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.9267 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6615100 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	3.903e+06 exact calculations (R>Rmax),
# 	2.712e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6615100 numbers in 219 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.5970 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 5468649 numbers in 187 CPU-chunks.
# root_add_process : ended.
# Workers processed 5468649 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	2.899e+06 exact calculations (R>Rmax),
# 	2.569e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 1.3615 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6044906 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	4.134e+06 exact calculations (R>Rmax),
# 	1.911e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6044906 numbers in 200 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.4702 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 7860773 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.191e+06 exact calculations (R>Rmax),
# 	1.669e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 7860773 numbers in 258 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.0813 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8202458 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.464e+06 exact calculations (R>Rmax),
# 	1.739e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8202458 numbers in 263 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.0575 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6126102 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	4.303e+06 exact calculations (R>Rmax),
# 	1.823e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6126102 numbers in 205 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.5143 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8708020 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.291e+06 exact calculations (R>Rmax),
# 	1.417e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8708020 numbers in 283 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.1912 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 15859372 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.510e+07 exact calculations (R>Rmax),
# 	7.558e+05 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 15859372 numbers in 503 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 3.5835 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 12227805 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.071e+07 exact calculations (R>Rmax),
# 	1.516e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 12227805 numbers in 391 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.6671 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 10769962 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	9.924e+06 exact calculations (R>Rmax),
# 	8.464e+05 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 10769962 numbers in 349 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.7322 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8069167 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.105e+06 exact calculations (R>Rmax),
# 	1.964e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8069167 numbers in 264 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.1002 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 13059977 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.146e+07 exact calculations (R>Rmax),
# 	1.604e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 13059977 numbers in 414 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.9930 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 12410896 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.002e+07 exact calculations (R>Rmax),
# 	2.387e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 12410896 numbers in 396 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.5992 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9729322 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.027e+06 exact calculations (R>Rmax),
# 	1.702e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9729322 numbers in 312 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.6901 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8118400 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	5.956e+06 exact calculations (R>Rmax),
# 	2.162e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8118400 numbers in 265 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.0050 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 12697245 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.075e+07 exact calculations (R>Rmax),
# 	1.950e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 12697245 numbers in 404 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.8721 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 13859166 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.219e+07 exact calculations (R>Rmax),
# 	1.669e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 13859166 numbers in 441 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 3.1962 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8737108 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.912e+06 exact calculations (R>Rmax),
# 	1.825e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8737108 numbers in 284 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.4344 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8513868 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.650e+06 exact calculations (R>Rmax),
# 	1.864e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8513868 numbers in 279 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.0068 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 10749452 numbers in 345 CPU-chunks.
# root_add_process : ended.
# Workers processed 10749452 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.869e+06 exact calculations (R>Rmax),
# 	1.880e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 2.4308 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9796944 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.775e+06 exact calculations (R>Rmax),
# 	2.022e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9796944 numbers in 319 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.0848 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6482913 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	4.191e+06 exact calculations (R>Rmax),
# 	2.292e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6482913 numbers in 214 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.5225 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6353979 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	3.762e+06 exact calculations (R>Rmax),
# 	2.592e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6353979 numbers in 207 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.6894 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 11802071 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.017e+07 exact calculations (R>Rmax),
# 	1.627e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 11802071 numbers in 379 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.6851 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 10993758 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.645e+06 exact calculations (R>Rmax),
# 	2.348e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 10993758 numbers in 353 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.2538 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9903872 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.871e+06 exact calculations (R>Rmax),
# 	1.033e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9903872 numbers in 316 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.5643 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 11584495 numbers in 370 CPU-chunks.
# root_add_process : ended.
# Workers processed 11584495 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.019e+07 exact calculations (R>Rmax),
# 	1.394e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 3.0015 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 17140554 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.621e+07 exact calculations (R>Rmax),
# 	9.284e+05 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 17140554 numbers in 539 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 4.1117 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 13091279 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.070e+07 exact calculations (R>Rmax),
# 	2.394e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 13091279 numbers in 418 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.8090 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8662052 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.592e+06 exact calculations (R>Rmax),
# 	2.070e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8662052 numbers in 285 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.3252 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 10787586 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	9.132e+06 exact calculations (R>Rmax),
# 	1.656e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 10787586 numbers in 344 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.6863 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 22398764 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	2.107e+07 exact calculations (R>Rmax),
# 	1.331e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 22398764 numbers in 700 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 4.6163 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 17028405 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.555e+07 exact calculations (R>Rmax),
# 	1.478e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 17028405 numbers in 535 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 3.6857 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9389250 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.728e+06 exact calculations (R>Rmax),
# 	1.661e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9389250 numbers in 305 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.4203 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6423632 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	3.847e+06 exact calculations (R>Rmax),
# 	2.576e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6423632 numbers in 213 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.4321 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 12239283 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	9.641e+06 exact calculations (R>Rmax),
# 	2.598e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 12239283 numbers in 390 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.2582 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 13730145 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.211e+07 exact calculations (R>Rmax),
# 	1.616e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 13730145 numbers in 437 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.8602 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8163901 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.443e+06 exact calculations (R>Rmax),
# 	1.721e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8163901 numbers in 270 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.9300 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 5432750 numbers in 186 CPU-chunks.
# root_add_process : ended.
# Workers processed 5432750 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	2.760e+06 exact calculations (R>Rmax),
# 	2.673e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 1.4600 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 6028439 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	3.331e+06 exact calculations (R>Rmax),
# 	2.697e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 6028439 numbers in 201 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.6713 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 2843833 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	4.594e+05 exact calculations (R>Rmax),
# 	2.384e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 2843833 numbers in 116 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.8833 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Root processed 5098283 numbers in 174 CPU-chunks.
# root_add_process : ended.
# Workers processed 5098283 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.795e+06 exact calculations (R>Rmax),
# 	3.303e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# voxelize_gpu function took 1.8063 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 7200684 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	4.799e+06 exact calculations (R>Rmax),
# 	2.401e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 7200684 numbers in 234 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.9306 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 8481278 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	6.046e+06 exact calculations (R>Rmax),
# 	2.435e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 8481278 numbers in 273 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.9859 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 4999861 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.788e+06 exact calculations (R>Rmax),
# 	3.212e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 4999861 numbers in 165 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.3721 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 4995915 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.886e+06 exact calculations (R>Rmax),
# 	3.110e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 4995915 numbers in 175 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.4110 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9604291 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.133e+06 exact calculations (R>Rmax),
# 	1.471e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9604291 numbers in 311 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.5352 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 13742993 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.259e+07 exact calculations (R>Rmax),
# 	1.152e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 13742993 numbers in 437 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 3.2037 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 12058288 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.040e+07 exact calculations (R>Rmax),
# 	1.659e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 12058288 numbers in 385 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.9169 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 7539615 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	5.470e+06 exact calculations (R>Rmax),
# 	2.069e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 7539615 numbers in 248 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.9767 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 5556271 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	3.375e+06 exact calculations (R>Rmax),
# 	2.181e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 5556271 numbers in 189 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 1.7017 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 11982098 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.020e+07 exact calculations (R>Rmax),
# 	1.778e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 11982098 numbers in 383 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.2595 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 16402435 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.583e+07 exact calculations (R>Rmax),
# 	5.765e+05 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 16402435 numbers in 513 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 3.5596 seconds
# In the end, 0 in cpu_queue
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 9270344 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	8.116e+06 exact calculations (R>Rmax),
# 	1.154e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 9270344 numbers in 301 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.4284 seconds
# In the end, 0 in cpu_queue

# %% [markdown]
# Examine result

# %% [markdown]
# Plot blocks

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

file = 'output/Ng256Nb64Nmargin10/r0s0t0.npy'
v_block = np.load(file)
im = axes[0, 0].imshow(v_block[:,:,40,0])
plt.colorbar(im, ax=axes[0, 0])
axes[0, 0].axhline(10, color='r')
axes[0, 0].axhline(74, color='r')
axes[0, 0].axvline(10, color='r')
axes[0, 0].axvline(74, color='r')

file = 'output/Ng256Nb64Nmargin10/r1s0t0.npy'
v_block = np.load(file)
im = axes[1, 0].imshow(v_block[:,:,40,0])
plt.colorbar(im, ax=axes[1, 0])
axes[1, 0].axhline(10, color='r')
axes[1, 0].axhline(74, color='r')
axes[1, 0].axvline(10, color='r')
axes[1, 0].axvline(74, color='r')

file = 'output/Ng256Nb64Nmargin10/r0s1t0.npy'
v_block = np.load(file)
im = axes[0, 1].imshow(v_block[:,:,40,0])
plt.colorbar(im, ax=axes[0, 1])
axes[0, 1].axhline(10, color='r')
axes[0, 1].axhline(74, color='r')
axes[0, 1].axvline(10, color='r')
axes[0, 1].axvline(74, color='r')

file = 'output/Ng256Nb64Nmargin10/r1s1t0.npy'
v_block = np.load(file)
im = axes[1, 1].imshow(v_block[:,:,40,0])
plt.colorbar(im, ax=axes[1, 1])
axes[1, 1].axhline(10, color='r')
axes[1, 1].axhline(74, color='r')
axes[1, 1].axvline(10, color='r')
axes[1, 1].axvline(74, color='r')

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

file = 'output/Ng128Nb64Nmargin10/r0s0t0.npy'
v_block = np.load(file)
im = axes[0, 0].imshow(v_block[10:-10,10:-10,40,0])
plt.colorbar(im, ax=axes[0, 0])
file = 'output/Ng128Nb64Nmargin10/r1s0t0.npy'
v_block = np.load(file)
im = axes[1, 0].imshow(v_block[10:-10,10:-10,40,0])
plt.colorbar(im, ax=axes[1, 0])
file = 'output/Ng128Nb64Nmargin10/r0s1t0.npy'
v_block = np.load(file)
im = axes[0, 1].imshow(v_block[10:-10,10:-10,40,0])
plt.colorbar(im, ax=axes[0, 1])
file = 'output/Ng128Nb64Nmargin10/r1s1t0.npy'
v_block = np.load(file)
im = axes[1, 1].imshow(v_block[10:-10,10:-10,40,0])
plt.colorbar(im, ax=axes[1, 1])
plt.show()

# %%
file = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind4_gmc9/snapshot_550.hdf5'
pos, mass, rho, v = dt.LoadSnapshot(file)
v_grid, m_grid = vxl.VoxelizeInterpolate(pos, mass, rho, v, Lbox=1., Nsize=128, smoothing_rate=2.)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 81272994 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	7.485e+07 exact calculations (R>Rmax),
# 	6.422e+06 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 81272994 numbers in 2499 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 10.9900 seconds
# In the end, 0 in cpu_queue

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

im = axes[0, 0].imshow(v_grid[:64,:64,30,0])
plt.colorbar(im, ax=axes[0, 0])
im = axes[1, 0].imshow(v_grid[64:,:64,30,0])
plt.colorbar(im, ax=axes[1, 0])
im = axes[0, 1].imshow(v_grid[:64,64:,30,0])
plt.colorbar(im, ax=axes[0, 1])
im = axes[1, 1].imshow(v_grid[64:,64:,30,0])
plt.colorbar(im, ax=axes[1, 1])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# current_cmap = plt.get_cmap().copy()
# current_cmap.set_bad(color='red')

file = 'output/Ng128Nb64Nmargin10/r0s0t0.npy'
v_block = np.load(file)
block = v_block[10:-10,10:-10,40,0]
grid = v_grid[:64,:64,30,0]
comparison = np.abs((block - grid) / grid)
# comparison[comparison == 0] = np.nan
print('{:.1%}'.format(len(comparison[comparison <= 1e-5])/64**2))
im = axes[0, 0].imshow(comparison, vmin=0, vmax=1)
plt.colorbar(im, ax=axes[0, 0])

file = 'output/Ng128Nb64Nmargin10/r1s0t0.npy'
v_block = np.load(file)
block = v_block[10:-10,10:-10,40,0]
grid = v_grid[64:,:64,30,0]
comparison = np.abs((block - grid) / grid)
# comparison[comparison == 0] = np.nan
print('{:.1%}'.format(len(comparison[comparison <= 1e-5])/64**2))
im = axes[1, 0].imshow(comparison, vmin=0, vmax=1)
plt.colorbar(im, ax=axes[1, 0])

file = 'output/Ng128Nb64Nmargin10/r0s1t0.npy'
v_block = np.load(file)
block = v_block[10:-10,10:-10,40,0]
grid = v_grid[:64,64:,30,0]
comparison = np.abs((block - grid) / grid)
# comparison[comparison == 0] = np.nan
print('{:.1%}'.format(len(comparison[comparison <= 1e-5])/64**2))
im = axes[0, 1].imshow(comparison, vmin=0, vmax=1)
plt.colorbar(im, ax=axes[0, 1])


file = 'output/Ng128Nb64Nmargin10/r1s1t0.npy'
v_block = np.load(file)
block = v_block[10:-10,10:-10,40,0]
grid = v_grid[64:,64:,30,0]
comparison = np.abs((block - grid) / grid)
# comparison[comparison == 0] = np.nan
print('{:.1%}'.format(len(comparison[comparison <= 1e-5])/64**2))
im = axes[1, 1].imshow(comparison, vmin=0, vmax=1)
plt.colorbar(im, ax=axes[1, 1])

plt.show()
# Out:
# 90.9%
# 83.3%
# 90.8%
# 87.3%

# %% [markdown]
# ### Debug
# line by line

# %%
smoothing_rate = 2.
Lbox = 1.
Nblock = 2
Nsize_blk = 64
margin = 10/64
scheme='voxelize'
file = '/appalachia/d5/DISK/from_pleiades/snapshots/gmcs0_wind4_gmc9/snapshot_550.hdf5'
pos, mass, rho, v = dt.PrepSnapshot(file)

# kny = 2*np.pi/Lbox
# k_kny_max = Nsize_blk * Nblock
Lbox_blk = Lbox / Nblock
Lbox_mgn = margin * Lbox_blk       # margin box length (margin box length)
Lbox_ext = Lbox_blk + 2 * Lbox_mgn
Nsize_mgn = int(margin * Nsize_blk)
Nsize_ext = Nsize_blk + 2 * Nsize_mgn
print('Sub-box length: {} Sub-box Nsize: {}'.format(Lbox_ext, Nsize_ext))
# Out:
# Sub-box length: 0.65625 Sub-box Nsize: 84

# %%
print(pos[:,0].min(), pos[:,0].max())
print(pos[:,1].min(), pos[:,1].max())
print(pos[:,2].min(), pos[:,2].max())
# Out:
# 0.0 0.9999977348045945
# 0.0 0.9999997896774175
# 0.0 0.9999979620489512

# %%
for r in range(Nblock): # 0, 1, 2, ..., Nblock-1
  for s in range(Nblock):  # Nblock*Lbox_blk=Lbox
    for t in range(Nblock):
      selection = (pos[:,0] >= r*Lbox_blk - Lbox_mgn) &\
        (pos[:,0] < (r+1)*Lbox_blk + Lbox_mgn) &\
        (pos[:,1] >= s*Lbox_blk - Lbox_mgn) &\
        (pos[:,1] < (s+1)*Lbox_blk + Lbox_mgn) &\
        (pos[:,2] >= t*Lbox_blk - Lbox_mgn) &\
        (pos[:,2] < (t+1)*Lbox_blk + Lbox_mgn)
      
      pos_blk =  pos[selection]
      rho_blk =  rho[selection]
      m_blk   = mass[selection]
      v_blk   =    v[selection]
      
      if scheme == 'voxelize':
        v_grid, m_grid = vxl.VoxelizeInterpolate(pos_blk, m_blk, rho_blk, v_blk, 
          Lbox=Lbox_ext, Nsize=Nsize_ext, smoothing_rate=smoothing_rate)
        m_grid = np.concatenate((m_grid[-Nsize_mgn:,:,:], m_grid[:-Nsize_mgn,:,:]), axis=0) # Shuffle to real
        m_grid = np.concatenate((m_grid[:,-Nsize_mgn:,:], m_grid[:,:-Nsize_mgn,:]), axis=1)
        m_grid = np.concatenate((m_grid[:,:,-Nsize_mgn:], m_grid[:,:,:-Nsize_mgn]), axis=2)
        v_grid = np.concatenate((v_grid[-Nsize_mgn:,:,:,:], v_grid[:-Nsize_mgn,:,:,:]), axis=0)
        v_grid = np.concatenate((v_grid[:,-Nsize_mgn:,:,:], v_grid[:,:-Nsize_mgn,:,:]), axis=1)
        v_grid = np.concatenate((v_grid[:,:,-Nsize_mgn:,:], v_grid[:,:,:-Nsize_mgn,:]), axis=2)
      else:
        raise Exception("Interpolation scheme unrecognized.")
      break # test run
    break
  break
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# root_add_process : started ...
# workers_process : started ...
# workers using 35 threads.
# Workers processed 19588475 numbers, of which were
# 	0.000e+00 exact calculations (R<Rmin),
# 	1.860e+07 exact calculations (R>Rmax),
# 	9.903e+05 trivial calculations,
# 	0.000e+00 interpolations.
#
# workers_process : ended.
# Root processed 19588475 numbers in 621 CPU-chunks.
# root_add_process : ended.
# voxelize_gpu function took 2.5131 seconds
# In the end, 0 in cpu_queue

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
fig1 = axes[0].imshow(np.log10(m_grid[:,:,40]))
plt.colorbar(fig1, ax=axes[0])
fig2 = axes[1].imshow(v_grid[:,:,40,0]) #debug
plt.colorbar(fig2, ax=axes[1])
plt.show()
# Out:
# /tmp/ipykernel_799628/338513030.py:2: RuntimeWarning: divide by zero encountered in log10
#   fig1 = axes[0].imshow(np.log10(m_grid[:,:,40]))
